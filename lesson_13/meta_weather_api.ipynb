# %% [markdown]
# [MetaWeather](https://www.metaweather.com) - это автоматический агрегатор данных о погоде, который принимает прогнозы погоды от различных прогнозистов и вычисляет наиболее вероятный результат.
#
# Идея состоит в том, что объединенные знания прогнозистов произведут лучшее предсказание.
#
# **История**
#
# Я (Джейсон) собирался на свадьбу друга, которая была частично на улице в климатически непредсказуемой Великобритании. При проверке прогноза погоды я задавался вопросом, должен ли я проверить другого прогнозиста, чтобы увидеть, что он предсказал - мыслительный процесс, который привел меня к проверке ряда сайтов. Пара плохо написанных PHP-скриптов, неуклюжая база данных MySQL и несколько часов спустя я перебирал данные о погоде с нескольких сайтов.
#
# Я приступил к созданию внешнего интерфейса и с тех пор собрал около миллиарда точек прогнозов и данных наблюдений по состоянию на начало 2017 года.
#
# Далее пример работы с API сайта:

# %%
import requests
import pandas as pd
from pprint import pprint as pp

# %% [markdown]
# Пример получения прогноза погоды в Санкт-Петербурге на 08.05.2019
#
# Для начала узнаем ID города:

# %%
json_city = requests.get("https://www.metaweather.com/api/location/search/?query=St Petersburg").json()

# %%
pp(json_city)
# Out:
# [{'latt_long': '59.932739,30.306721',
#   'location_type': 'City',
#   'title': 'St Petersburg',
#   'woeid': 2123260}]

# %%
ident = json_city[0]["woeid"]

# %%
print(ident)
# Out:
# 2123260

# %%
pp(requests.get("https://www.metaweather.com/api/location/"+ str(ident)+"/2019/5/24/").json())
# Out:
# [{'air_pressure': 1017.4549999999999,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-23T05:30:11.015041Z',
#   'humidity': 55,
#   'id': 6355016275197952,
#   'max_temp': 22.705,
#   'min_temp': 14.955,
#   'predictability': 71,
#   'the_temp': 22.310000000000002,
#   'visibility': 15.89094687027758,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 96.45624660777841,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.659250361244996},
#  {'air_pressure': 1017.4549999999999,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-23T02:28:11.359446Z',
#   'humidity': 55,
#   'id': 4708573781164032,
#   'max_temp': 22.705,
#   'min_temp': 15.62,
#   'predictability': 71,
#   'the_temp': 22.4,
#   'visibility': 16.840402052016223,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 96.45624660777841,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.64433749457833},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T23:26:11.879466Z',
#   'humidity': 56,
#   'id': 6135392686309376,
#   'max_temp': 22.82,
#   'min_temp': 15.135,
#   'predictability': 71,
#   'the_temp': 22.39,
#   'visibility': 12.46190994591585,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 89.93467247604046,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.704817791744214},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T20:24:14.124284Z',
#   'humidity': 56,
#   'id': 6635820767248384,
#   'max_temp': 23.83,
#   'min_temp': 15.34,
#   'predictability': 71,
#   'the_temp': 22.39,
#   'visibility': 12.412200250536863,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 86.61658540206902,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.948151125077548},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T17:22:14.484711Z',
#   'humidity': 56,
#   'id': 6751437662978048,
#   'max_temp': 23.83,
#   'min_temp': 15.34,
#   'predictability': 71,
#   'the_temp': 22.055,
#   'visibility': 15.05178507516106,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 86.61658540206902,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.030171891744214},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T14:20:14.079461Z',
#   'humidity': 58,
#   'id': 5808910445314048,
#   'max_temp': 23.83,
#   'min_temp': 15.34,
#   'predictability': 71,
#   'the_temp': 21.595,
#   'visibility': 9.89844309234073,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 86.61658540206902,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.119649091744214},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T11:18:13.873815Z',
#   'humidity': 61,
#   'id': 6390286076870656,
#   'max_temp': 21.02,
#   'min_temp': 15.65,
#   'predictability': 71,
#   'the_temp': 21.595,
#   'visibility': 9.519406665075955,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.46460312676187,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.2629824250775465},
#  {'air_pressure': 1016.78,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T08:16:13.766070Z',
#   'humidity': 61,
#   'id': 5913752643829760,
#   'max_temp': 21.02,
#   'min_temp': 15.65,
#   'predictability': 71,
#   'the_temp': 21.560000000000002,
#   'visibility': 9.237304143800207,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.46460312676187,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.233156691744214},
#  {'air_pressure': 1016.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T05:14:13.743612Z',
#   'humidity': 63,
#   'id': 6138065061937152,
#   'max_temp': 21.02,
#   'min_temp': 15.65,
#   'predictability': 71,
#   'the_temp': 22.305,
#   'visibility': 11.645428199315994,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.46460312676187,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.225700258410881},
#  {'air_pressure': 1015.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-22T02:12:13.656948Z',
#   'humidity': 63,
#   'id': 6561220943413248,
#   'max_temp': 21.02,
#   'min_temp': 15.65,
#   'predictability': 71,
#   'the_temp': 22.875,
#   'visibility': 12.431152071900105,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 96.05821924384078,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.285351725077547},
#  {'air_pressure': 1015.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T23:10:13.179831Z',
#   'humidity': 63,
#   'id': 4721764431036416,
#   'max_temp': 21.02,
#   'min_temp': 15.65,
#   'predictability': 71,
#   'the_temp': 22.875,
#   'visibility': 12.431152071900105,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 96.05821924384078,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.285351725077547},
#  {'air_pressure': 1015.56,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T20:08:17.358422Z',
#   'humidity': 64,
#   'id': 5154848834060288,
#   'max_temp': 20.405,
#   'min_temp': 15.675,
#   'predictability': 71,
#   'the_temp': 22.655,
#   'visibility': 12.431152071900105,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.6145052891028,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.262568114695512},
#  {'air_pressure': 1015.56,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T17:06:16.379877Z',
#   'humidity': 64,
#   'id': 6457540432887808,
#   'max_temp': 20.405,
#   'min_temp': 15.675,
#   'predictability': 71,
#   'the_temp': 22.655,
#   'visibility': 12.431152071900105,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.6145052891028,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.262568114695512},
#  {'air_pressure': 1015.56,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T14:04:16.596859Z',
#   'humidity': 63,
#   'id': 5589038587183104,
#   'max_temp': 20.405,
#   'min_temp': 15.675,
#   'predictability': 71,
#   'the_temp': 22.95,
#   'visibility': 13.15225334049153,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.6145052891028,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.225285948028845},
#  {'air_pressure': 1014.9549999999999,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T11:02:16.989568Z',
#   'humidity': 69,
#   'id': 4936706237136896,
#   'max_temp': 23.0,
#   'min_temp': 16.095,
#   'predictability': 73,
#   'the_temp': 22.75,
#   'visibility': 11.332878489620615,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 107.72381839541582,
#   'wind_direction_compass': 'ESE',
#   'wind_speed': 4.31304019319176},
#  {'air_pressure': 1014.9549999999999,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T08:00:17.184632Z',
#   'humidity': 69,
#   'id': 4534153280225280,
#   'max_temp': 23.0,
#   'min_temp': 16.095,
#   'predictability': 73,
#   'the_temp': 22.75,
#   'visibility': 11.332878489620615,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 107.72381839541582,
#   'wind_direction_compass': 'ESE',
#   'wind_speed': 4.31304019319176},
#  {'air_pressure': 1015.645,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T04:58:18.047772Z',
#   'humidity': 65,
#   'id': 4679752671559680,
#   'max_temp': 22.34,
#   'min_temp': 15.889999999999999,
#   'predictability': 71,
#   'the_temp': 22.175,
#   'visibility': 10.105670384951882,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 98.25000000000001,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.7235594904504365},
#  {'air_pressure': 1016.145,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-21T01:56:16.590739Z',
#   'humidity': 65,
#   'id': 5001983163367424,
#   'max_temp': 21.77,
#   'min_temp': 16.35,
#   'predictability': 71,
#   'the_temp': 22.115000000000002,
#   'visibility': 10.569213294360932,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 70.04509319962179,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.57627732378377},
#  {'air_pressure': 1014.645,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T22:54:16.264875Z',
#   'humidity': 66,
#   'id': 4867125552349184,
#   'max_temp': 21.77,
#   'min_temp': 16.35,
#   'predictability': 71,
#   'the_temp': 22.695,
#   'visibility': 10.061553030303031,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.48129167971022,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.613559490450436},
#  {'air_pressure': 1015.145,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T19:52:19.909520Z',
#   'humidity': 65,
#   'id': 5064054030729216,
#   'max_temp': 21.77,
#   'min_temp': 16.145,
#   'predictability': 71,
#   'the_temp': 22.915,
#   'visibility': 10.277790205201622,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 88.48129167971022,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.583733757117103},
#  {'air_pressure': 1017.0350000000001,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T16:50:20.329323Z',
#   'humidity': 65,
#   'id': 6140024372330496,
#   'max_temp': 20.255,
#   'min_temp': 16.385,
#   'predictability': 71,
#   'the_temp': 22.615000000000002,
#   'visibility': 13.77611001749781,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 82.94526750401656,
#   'wind_direction_compass': 'E',
#   'wind_speed': 5.388623495564569},
#  {'air_pressure': 1017.0350000000001,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T13:48:19.964775Z',
#   'humidity': 63,
#   'id': 4918764749455360,
#   'max_temp': 20.255,
#   'min_temp': 16.385,
#   'predictability': 71,
#   'the_temp': 22.8,
#   'visibility': 16.16838910761155,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 75.51468936748644,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 5.388623495564569},
#  {'air_pressure': 1017.5350000000001,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T10:46:19.193611Z',
#   'humidity': 65,
#   'id': 6145025727528960,
#   'max_temp': 21.61,
#   'min_temp': 16.580000000000002,
#   'predictability': 71,
#   'the_temp': 23.17,
#   'visibility': 13.369733257774596,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 81.47414562205908,
#   'wind_direction_compass': 'E',
#   'wind_speed': 4.443966462231235},
#  {'air_pressure': 1017.12,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T07:44:20.055991Z',
#   'humidity': 66,
#   'id': 6000606613340160,
#   'max_temp': 21.62,
#   'min_temp': 16.47,
#   'predictability': 71,
#   'the_temp': 23.085,
#   'visibility': 11.63735037381691,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 76.28944894453213,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.607593685182533},
#  {'air_pressure': 1017.14,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T04:42:19.381774Z',
#   'humidity': 68,
#   'id': 4822756191371264,
#   'max_temp': 20.935,
#   'min_temp': 16.39,
#   'predictability': 71,
#   'the_temp': 21.945,
#   'visibility': 14.730225483178238,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 55.91006166885554,
#   'wind_direction_compass': 'NE',
#   'wind_speed': 4.227728322550969},
#  {'air_pressure': 1016.14,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-20T01:40:20.256355Z',
#   'humidity': 71,
#   'id': 4538120118730752,
#   'max_temp': 20.935,
#   'min_temp': 16.39,
#   'predictability': 71,
#   'the_temp': 21.630000000000003,
#   'visibility': 15.16332120416766,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 35.935150355717326,
#   'wind_direction_compass': 'NE',
#   'wind_speed': 4.525985655884302},
#  {'air_pressure': 1016.64,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T22:38:19.863012Z',
#   'humidity': 72,
#   'id': 5794069085159424,
#   'max_temp': 20.935,
#   'min_temp': 16.39,
#   'predictability': 71,
#   'the_temp': 21.36,
#   'visibility': 14.74389564940746,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 35.935150355717326,
#   'wind_direction_compass': 'NE',
#   'wind_speed': 4.555811389217635},
#  {'air_pressure': 1020.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T19:36:22.730113Z',
#   'humidity': 67,
#   'id': 6351190365306880,
#   'max_temp': 18.665,
#   'min_temp': 15.68,
#   'predictability': 70,
#   'the_temp': 27.35,
#   'visibility': 8.550067605185715,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 32.99999999999999,
#   'wind_direction_compass': 'NNE',
#   'wind_speed': 5.803983933826453},
#  {'air_pressure': 1020.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T16:34:22.679159Z',
#   'humidity': 67,
#   'id': 5219049434775552,
#   'max_temp': 18.665,
#   'min_temp': 15.68,
#   'predictability': 70,
#   'the_temp': 27.35,
#   'visibility': 8.550067605185715,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 32.99999999999999,
#   'wind_direction_compass': 'NNE',
#   'wind_speed': 5.803983933826453},
#  {'air_pressure': 1020.28,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T13:32:22.565446Z',
#   'humidity': 67,
#   'id': 5629411950854144,
#   'max_temp': 18.665,
#   'min_temp': 15.68,
#   'predictability': 70,
#   'the_temp': 27.35,
#   'visibility': 8.550067605185715,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 32.99999999999999,
#   'wind_direction_compass': 'NNE',
#   'wind_speed': 5.803983933826453},
#  {'air_pressure': 1020.36,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T10:30:23.246779Z',
#   'humidity': 60,
#   'id': 4554622154833920,
#   'max_temp': 20.830000000000002,
#   'min_temp': 14.485,
#   'predictability': 70,
#   'the_temp': 27.4,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 71.5,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.833693629205441},
#  {'air_pressure': 1020.36,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T07:28:22.863157Z',
#   'humidity': 60,
#   'id': 6403175173062656,
#   'max_temp': 20.830000000000002,
#   'min_temp': 14.485,
#   'predictability': 70,
#   'the_temp': 27.4,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 71.5,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.833693629205441},
#  {'air_pressure': 1020.21,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T04:26:22.476860Z',
#   'humidity': 59,
#   'id': 4952967620853760,
#   'max_temp': 20.705000000000002,
#   'min_temp': 14.29,
#   'predictability': 70,
#   'the_temp': 27.52,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 77.5,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.948647299769347},
#  {'air_pressure': 1020.21,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-19T01:24:23.480135Z',
#   'humidity': 58,
#   'id': 5158123008425984,
#   'max_temp': 20.39,
#   'min_temp': 13.739999999999998,
#   'predictability': 68,
#   'the_temp': 27.52,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 61.0,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.578647299769347},
#  {'air_pressure': 1020.21,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T22:22:22.163434Z',
#   'humidity': 58,
#   'id': 6338837468938240,
#   'max_temp': 20.39,
#   'min_temp': 13.739999999999998,
#   'predictability': 68,
#   'the_temp': 27.52,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 61.0,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.578647299769347},
#  {'air_pressure': 1020.21,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T19:20:26.111080Z',
#   'humidity': 58,
#   'id': 4890522554466304,
#   'max_temp': 20.39,
#   'min_temp': 13.739999999999998,
#   'predictability': 68,
#   'the_temp': 27.52,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 61.0,
#   'wind_direction_compass': 'ENE',
#   'wind_speed': 4.578647299769347},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T16:18:25.982718Z',
#   'humidity': 52,
#   'id': 5378254477197312,
#   'max_temp': 19.605,
#   'min_temp': 13.989999999999998,
#   'predictability': 68,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 324.0,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 4.674959834566134},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T13:16:25.730656Z',
#   'humidity': 52,
#   'id': 4970024915697664,
#   'max_temp': 19.605,
#   'min_temp': 13.989999999999998,
#   'predictability': 68,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 324.0,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 4.674959834566134},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T10:14:25.661608Z',
#   'humidity': 53,
#   'id': 4715166119755776,
#   'max_temp': 20.34,
#   'min_temp': 15.465,
#   'predictability': 70,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 342.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 5.494959834566133},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T07:12:26.559220Z',
#   'humidity': 53,
#   'id': 6667074136965120,
#   'max_temp': 20.34,
#   'min_temp': 15.465,
#   'predictability': 70,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 342.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 5.494959834566133},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T04:10:25.676877Z',
#   'humidity': 53,
#   'id': 5705067665555456,
#   'max_temp': 20.34,
#   'min_temp': 15.465,
#   'predictability': 70,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 342.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 5.494959834566133},
#  {'air_pressure': 1017.94,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-18T01:08:25.213267Z',
#   'humidity': 53,
#   'id': 5750043355119616,
#   'max_temp': 20.34,
#   'min_temp': 15.465,
#   'predictability': 70,
#   'the_temp': 26.53,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 342.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 5.494959834566133},
#  {'air_pressure': 1018.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T22:06:28.880765Z',
#   'humidity': 56,
#   'id': 6149366496624640,
#   'max_temp': 20.115,
#   'min_temp': 14.52,
#   'predictability': 68,
#   'the_temp': 26.59,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 16.49999999999999,
#   'wind_direction_compass': 'NNE',
#   'wind_speed': 4.893125347967867},
#  {'air_pressure': 1018.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T19:04:29.990557Z',
#   'humidity': 62,
#   'id': 6265318332694528,
#   'max_temp': 20.055,
#   'min_temp': 14.645,
#   'predictability': 70,
#   'the_temp': 26.59,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 334.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 3.8831253479678676},
#  {'air_pressure': 1018.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T16:02:28.877023Z',
#   'humidity': 62,
#   'id': 5862531400728576,
#   'max_temp': 20.055,
#   'min_temp': 14.645,
#   'predictability': 70,
#   'the_temp': 26.59,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 334.0,
#   'wind_direction_compass': 'NNW',
#   'wind_speed': 3.8831253479678676},
#  {'air_pressure': 1019.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T13:00:28.957542Z',
#   'humidity': 68,
#   'id': 6382848703463424,
#   'max_temp': 20.255000000000003,
#   'min_temp': 14.64,
#   'predictability': 70,
#   'the_temp': 27.07,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 313.5,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 3.184082756700867},
#  {'air_pressure': 1019.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T09:58:28.244489Z',
#   'humidity': 68,
#   'id': 5369184009584640,
#   'max_temp': 20.255000000000003,
#   'min_temp': 14.64,
#   'predictability': 70,
#   'the_temp': 27.07,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 313.5,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 3.184082756700867},
#  {'air_pressure': 1019.01,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T06:56:28.661518Z',
#   'humidity': 68,
#   'id': 5482100377518080,
#   'max_temp': 20.255000000000003,
#   'min_temp': 14.64,
#   'predictability': 70,
#   'the_temp': 27.07,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 313.5,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 3.184082756700867},
#  {'air_pressure': 1017.77,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T03:54:28.879546Z',
#   'humidity': 64,
#   'id': 6286588520693760,
#   'max_temp': 19.955,
#   'min_temp': 14.86,
#   'predictability': 70,
#   'the_temp': 26.25,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 305.0,
#   'wind_direction_compass': 'NW',
#   'wind_speed': 3.5817603197327603},
#  {'air_pressure': 1017.77,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-17T00:52:29.683131Z',
#   'humidity': 70,
#   'id': 5375866374717440,
#   'max_temp': 26.95,
#   'min_temp': 24.99,
#   'predictability': 68,
#   'the_temp': 26.25,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 267.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 1.3235206394655212},
#  {'air_pressure': 1017.33,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T21:15:42.761984Z',
#   'humidity': 71,
#   'id': 6029680756916224,
#   'max_temp': 27.36,
#   'min_temp': 25.85,
#   'predictability': 68,
#   'the_temp': 27.05,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 267.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 2.087807205917442},
#  {'air_pressure': 1017.33,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T18:48:31.564315Z',
#   'humidity': 71,
#   'id': 5575994771505152,
#   'max_temp': 27.36,
#   'min_temp': 25.85,
#   'predictability': 68,
#   'the_temp': 27.05,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 267.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 2.087807205917442},
#  {'air_pressure': 1016.03,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T15:46:32.179906Z',
#   'humidity': 78,
#   'id': 5096556162187264,
#   'max_temp': 28.02,
#   'min_temp': 24.89,
#   'predictability': 77,
#   'the_temp': 27.25,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 350.0,
#   'wind_direction_compass': 'N',
#   'wind_speed': 0.41010498687664043},
#  {'air_pressure': 1016.03,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T12:44:31.790189Z',
#   'humidity': 78,
#   'id': 4949554027823104,
#   'max_temp': 28.02,
#   'min_temp': 24.89,
#   'predictability': 77,
#   'the_temp': 27.25,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 350.0,
#   'wind_direction_compass': 'N',
#   'wind_speed': 0.41010498687664043},
#  {'air_pressure': 1016.03,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T09:42:31.890108Z',
#   'humidity': 78,
#   'id': 6133429886255104,
#   'max_temp': 28.02,
#   'min_temp': 24.89,
#   'predictability': 77,
#   'the_temp': 27.25,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 350.0,
#   'wind_direction_compass': 'N',
#   'wind_speed': 0.41010498687664043},
#  {'air_pressure': 1016.03,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T06:40:32.430259Z',
#   'humidity': 78,
#   'id': 4914874515718144,
#   'max_temp': 28.02,
#   'min_temp': 24.89,
#   'predictability': 77,
#   'the_temp': 27.25,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 350.0,
#   'wind_direction_compass': 'N',
#   'wind_speed': 0.41010498687664043},
#  {'air_pressure': 1019.5,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T03:38:31.699882Z',
#   'humidity': 76,
#   'id': 4506315315478528,
#   'max_temp': 27.73,
#   'min_temp': 27.05,
#   'predictability': 68,
#   'the_temp': 27.56,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 294.0,
#   'wind_direction_compass': 'WNW',
#   'wind_speed': 1.627992523661815},
#  {'air_pressure': 1019.5,
#   'applicable_date': '2019-05-24',
#   'created': '2019-05-16T00:36:31.519448Z',
#   'humidity': 76,
#   'id': 6306339833774080,
#   'max_temp': 27.73,
#   'min_temp': 27.05,
#   'predictability': 68,
#   'the_temp': 27.56,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 294.0,
#   'wind_direction_compass': 'WNW',
#   'wind_speed': 1.627992523661815}]

# %% [markdown]
# Данные на сайте собираются из разных источников. Можно посмотреть такие параметры, как атмосферное давление, максимальная и минимальная температура, скорость ветра, влажность, видимость и вероятность(предсказуемость) данного прогнозам.

# %%
pd.DataFrame(requests.get("https://www.metaweather.com/api/location/"+ str(ident)+"/2019/5/23/").json()).head()
# Out:
#    air_pressure applicable_date                      created  humidity  \
# 0      1015.915      2019-05-23  2019-05-23T05:30:07.900657Z        67
# 1      1015.035      2019-05-23  2019-05-23T02:28:07.678026Z        69
# 2      1015.935      2019-05-23  2019-05-22T23:26:08.336656Z        68
# 3      1015.935      2019-05-23  2019-05-22T20:24:11.299724Z        67
# 4      1015.935      2019-05-23  2019-05-22T17:22:11.543046Z        68
#
#                  id  max_temp  min_temp  predictability  the_temp  visibility  \
# 0  4650413783515136    19.055    15.815              70    19.245   19.441462
# 1  4954491394719744    21.595    17.165              73    21.790   19.587484
# 2  5044102531907584    22.040    16.700              70    21.825   15.596106
# 3  4821025017561088    21.870    16.725              70    21.825   15.735915
# 4  4509871246409728    21.870    16.725              70    21.795   17.316372
#
#   weather_state_abbr weather_state_name  wind_direction  \
# 0                 lc        Light Cloud       64.957469
# 1                  s            Showers       35.176430
# 2                 lc        Light Cloud       43.669080
# 3                 lc        Light Cloud       43.669080
# 4                 lc        Light Cloud       43.669080
#
#   wind_direction_compass  wind_speed
# 0                    ENE    7.614996
# 1                     NE    6.322544
# 2                     NE    6.207798
# 3                     NE    6.351131
# 4                     NE    6.343675
