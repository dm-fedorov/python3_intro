# %% [markdown]
# [MetaWeather](https://www.metaweather.com) - это автоматический агрегатор данных о погоде, который принимает прогнозы погоды от различных прогнозистов и вычисляет наиболее вероятный результат.
#
# Идея состоит в том, что объединенные знания прогнозистов произведут лучшее предсказание.
#
# **История**
#
# Я (Джейсон) собирался на свадьбу друга, которая была частично на улице в климатически непредсказуемой Великобритании. При проверке прогноза погоды я задавался вопросом, должен ли я проверить другого прогнозиста, чтобы увидеть, что он предсказал - мыслительный процесс, который привел меня к проверке ряда сайтов. Пара плохо написанных PHP-скриптов, неуклюжая база данных MySQL и несколько часов спустя я перебирал данные о погоде с нескольких сайтов.
#
# Я приступил к созданию внешнего интерфейса и с тех пор собрал около миллиарда точек прогнозов и данных наблюдений по состоянию на начало 2017 года.
#
# Далее пример работы с API сайта:

# %%
import requests
import pandas as pd
from pprint import pprint as pp

# %% [markdown]
# Пример получения прогноза погоды в Санкт-Петербурге на 08.05.2019
#
# Для начала узнаем ID города:

# %%
json_city = requests.get("https://www.metaweather.com/api/location/search/?query=St Petersburg").json()

# %%
pp(json_city)
# Out:
# [{'latt_long': '59.932739,30.306721',
#   'location_type': 'City',
#   'title': 'St Petersburg',
#   'woeid': 2123260}]

# %%
ident = json_city[0]["woeid"]

# %%
print(ident)
# Out:
# 2123260

# %%
pp(requests.get("https://www.metaweather.com/api/location/"+ str(ident)+"/2019/5/8/").json())
# Out:
# [{'air_pressure': 1016.52,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-07T13:23:10.693470Z',
#   'humidity': 57,
#   'id': 4629226038755328,
#   'max_temp': 19.145,
#   'min_temp': 12.435,
#   'predictability': 70,
#   'the_temp': 19.525,
#   'visibility': 16.460744253559213,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 251.23843398707248,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.9442101546833164},
#  {'air_pressure': 1016.52,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-07T10:21:11.596971Z',
#   'humidity': 57,
#   'id': 5305197318373376,
#   'max_temp': 19.145,
#   'min_temp': 12.435,
#   'predictability': 70,
#   'the_temp': 19.525,
#   'visibility': 16.460744253559213,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 251.23843398707248,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.9442101546833164},
#  {'air_pressure': 1016.52,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-07T07:19:11.369930Z',
#   'humidity': 58,
#   'id': 5199902705451008,
#   'max_temp': 19.145,
#   'min_temp': 12.435,
#   'predictability': 70,
#   'the_temp': 19.445,
#   'visibility': 17.48880289111588,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 251.23843398707248,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.824907221349983},
#  {'air_pressure': 1015.95,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-07T04:17:10.663412Z',
#   'humidity': 63,
#   'id': 5651761383604224,
#   'max_temp': 19.84,
#   'min_temp': 12.94,
#   'predictability': 70,
#   'the_temp': 19.505,
#   'visibility': 17.48880289111588,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 267.74146724755815,
#   'wind_direction_compass': 'W',
#   'wind_speed': 3.36095006447944},
#  {'air_pressure': 1010.95,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-07T01:15:11.856425Z',
#   'humidity': 79,
#   'id': 5401657854656512,
#   'max_temp': 19.84,
#   'min_temp': 12.94,
#   'predictability': 73,
#   'the_temp': 17.14,
#   'visibility': 6.955629125904716,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 303.5,
#   'wind_direction_compass': 'WNW',
#   'wind_speed': 3.5026222978127737},
#  {'air_pressure': 1011.03,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T22:13:11.155566Z',
#   'humidity': 79,
#   'id': 6118517088714752,
#   'max_temp': 19.695,
#   'min_temp': 12.935,
#   'predictability': 73,
#   'the_temp': 17.085,
#   'visibility': 6.955629125904716,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 293.5,
#   'wind_direction_compass': 'WNW',
#   'wind_speed': 3.4529126024337864},
#  {'air_pressure': 1016.03,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T19:11:13.773368Z',
#   'humidity': 65,
#   'id': 5752813374144512,
#   'max_temp': 19.375,
#   'min_temp': 13.13,
#   'predictability': 70,
#   'the_temp': 19.97,
#   'visibility': 16.62447556271375,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 264.65544607004205,
#   'wind_direction_compass': 'W',
#   'wind_speed': 3.487465802433787},
#  {'air_pressure': 1016.25,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T16:09:13.583096Z',
#   'humidity': 65,
#   'id': 6192618025254912,
#   'max_temp': 19.83,
#   'min_temp': 13.14,
#   'predictability': 73,
#   'the_temp': 19.96,
#   'visibility': 16.62447556271375,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 262.2439897733517,
#   'wind_direction_compass': 'W',
#   'wind_speed': 3.5641015828097244},
#  {'air_pressure': 1015.75,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T13:07:13.151853Z',
#   'humidity': 63,
#   'id': 5794986060677120,
#   'max_temp': 20.045,
#   'min_temp': 13.475000000000001,
#   'predictability': 73,
#   'the_temp': 19.665,
#   'visibility': 15.762944404676688,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 271.6706334490161,
#   'wind_direction_compass': 'W',
#   'wind_speed': 4.024286982809724},
#  {'air_pressure': 1016.345,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T10:05:12.951700Z',
#   'humidity': 60,
#   'id': 4515092047593472,
#   'max_temp': 19.035,
#   'min_temp': 13.555,
#   'predictability': 70,
#   'the_temp': 19.55,
#   'visibility': 15.762944404676688,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 267.3790810942821,
#   'wind_direction_compass': 'W',
#   'wind_speed': 4.769932413494526},
#  {'air_pressure': 1016.345,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T07:03:13.567015Z',
#   'humidity': 60,
#   'id': 4545797842534400,
#   'max_temp': 19.035,
#   'min_temp': 13.555,
#   'predictability': 70,
#   'the_temp': 19.55,
#   'visibility': 15.762944404676688,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 267.3790810942821,
#   'wind_direction_compass': 'W',
#   'wind_speed': 4.769932413494526},
#  {'air_pressure': 1015.625,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T04:01:13.067185Z',
#   'humidity': 63,
#   'id': 5362508355338240,
#   'max_temp': 19.635,
#   'min_temp': 13.420000000000002,
#   'predictability': 70,
#   'the_temp': 19.71,
#   'visibility': 16.663311262228582,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 208.2081435404625,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 4.018901786783849},
#  {'air_pressure': 1010.125,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-06T00:59:13.766378Z',
#   'humidity': 79,
#   'id': 6522862758264832,
#   'max_temp': 19.635,
#   'min_temp': 13.420000000000002,
#   'predictability': 71,
#   'the_temp': 17.35,
#   'visibility': 7.032057782549908,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 232.59826018070143,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 3.884685986783849},
#  {'air_pressure': 1015.625,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T21:57:16.581884Z',
#   'humidity': 63,
#   'id': 4701838735572992,
#   'max_temp': 19.635,
#   'min_temp': 13.420000000000002,
#   'predictability': 70,
#   'the_temp': 19.705000000000002,
#   'visibility': 16.435889405869723,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 216.97963601158355,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.1158354201171825},
#  {'air_pressure': 1015.625,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T18:55:17.791530Z',
#   'humidity': 64,
#   'id': 5497463945297920,
#   'max_temp': 19.060000000000002,
#   'min_temp': 13.71,
#   'predictability': 70,
#   'the_temp': 19.705000000000002,
#   'visibility': 16.435889405869723,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 218.61733815935673,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.1591687534505155},
#  {'air_pressure': 1015.315,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T15:53:16.330202Z',
#   'humidity': 64,
#   'id': 6732230133022720,
#   'max_temp': 18.54,
#   'min_temp': 13.515,
#   'predictability': 70,
#   'the_temp': 19.59,
#   'visibility': 16.435889405869723,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 223.84156129824854,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.219234635366791},
#  {'air_pressure': 1015.315,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T12:51:15.965763Z',
#   'humidity': 64,
#   'id': 5181463471325184,
#   'max_temp': 18.54,
#   'min_temp': 13.515,
#   'predictability': 70,
#   'the_temp': 19.59,
#   'visibility': 16.435889405869723,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 223.84156129824854,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.219234635366791},
#  {'air_pressure': 1015.99,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T09:49:17.751317Z',
#   'humidity': 59,
#   'id': 5962738893324288,
#   'max_temp': 19.195,
#   'min_temp': 13.6,
#   'predictability': 70,
#   'the_temp': 20.085,
#   'visibility': 15.85086842837827,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 244.0715665288127,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.158185427757894},
#  {'air_pressure': 1015.99,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T06:47:16.668656Z',
#   'humidity': 59,
#   'id': 5079980440551424,
#   'max_temp': 19.195,
#   'min_temp': 13.6,
#   'predictability': 70,
#   'the_temp': 20.085,
#   'visibility': 15.85086842837827,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 244.0715665288127,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.158185427757894},
#  {'air_pressure': 1015.3299999999999,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T03:45:16.587345Z',
#   'humidity': 62,
#   'id': 6418430024482816,
#   'max_temp': 19.095,
#   'min_temp': 13.690000000000001,
#   'predictability': 70,
#   'the_temp': 19.9,
#   'visibility': 16.113708442694662,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 221.37828730687067,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.733806767899467},
#  {'air_pressure': 1009.3299999999999,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-05T00:43:16.251599Z',
#   'humidity': 77,
#   'id': 6324477380001792,
#   'max_temp': 19.095,
#   'min_temp': 13.690000000000001,
#   'predictability': 71,
#   'the_temp': 19.09,
#   'visibility': 6.82203431957369,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 228.9842109846882,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 4.599590967899467},
#  {'air_pressure': 1014.875,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T21:41:19.581739Z',
#   'humidity': 60,
#   'id': 4767568915070976,
#   'max_temp': 19.095,
#   'min_temp': 14.145,
#   'predictability': 70,
#   'the_temp': 20.060000000000002,
#   'visibility': 14.753837588483258,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 227.99572330791148,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 5.126513340419947},
#  {'air_pressure': 1014.875,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T18:39:20.152064Z',
#   'humidity': 59,
#   'id': 6240531673776128,
#   'max_temp': 19.34,
#   'min_temp': 13.81,
#   'predictability': 70,
#   'the_temp': 19.83,
#   'visibility': 16.766148194543863,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 240.22064185197326,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.291251940419947},
#  {'air_pressure': 1014.875,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T15:37:19.169335Z',
#   'humidity': 59,
#   'id': 4927634595119104,
#   'max_temp': 19.34,
#   'min_temp': 13.81,
#   'predictability': 70,
#   'the_temp': 19.83,
#   'visibility': 16.766148194543863,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 240.22064185197326,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.291251940419947},
#  {'air_pressure': 1014.875,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T12:35:18.967884Z',
#   'humidity': 59,
#   'id': 6042338126200832,
#   'max_temp': 19.34,
#   'min_temp': 13.81,
#   'predictability': 70,
#   'the_temp': 19.77,
#   'visibility': 15.475249542670802,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 232.6107158053652,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 5.455293473753282},
#  {'air_pressure': 1014.51,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T09:33:19.051261Z',
#   'humidity': 62,
#   'id': 4897947781169152,
#   'max_temp': 19.145,
#   'min_temp': 13.905,
#   'predictability': 71,
#   'the_temp': 19.384999999999998,
#   'visibility': 14.52952258808558,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 235.08825781271096,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 5.7444380760332985},
#  {'air_pressure': 1014.51,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T06:31:20.387550Z',
#   'humidity': 64,
#   'id': 4534699546378240,
#   'max_temp': 19.145,
#   'min_temp': 13.905,
#   'predictability': 70,
#   'the_temp': 19.25,
#   'visibility': 15.187865366261036,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 235.08825781271096,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 5.565483676033299},
#  {'air_pressure': 1010.01,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T03:29:19.465381Z',
#   'humidity': 75,
#   'id': 5647002358513664,
#   'max_temp': 19.145,
#   'min_temp': 13.905,
#   'predictability': 71,
#   'the_temp': 18.175,
#   'visibility': 9.96151226835282,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 249.7460610119055,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.3194213760333},
#  {'air_pressure': 1010.01,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-04T00:27:20.176630Z',
#   'humidity': 75,
#   'id': 4646331417100288,
#   'max_temp': 19.145,
#   'min_temp': 13.905,
#   'predictability': 71,
#   'the_temp': 18.175,
#   'visibility': 9.96151226835282,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 249.7460610119055,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 5.3194213760333},
#  {'air_pressure': 1016.66,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T21:25:22.377378Z',
#   'humidity': 68,
#   'id': 5954577348165632,
#   'max_temp': 19.07,
#   'min_temp': 13.745,
#   'predictability': 73,
#   'the_temp': 25.51,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 233.5,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 5.3246416925157085},
#  {'air_pressure': 1016.66,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T18:23:22.192073Z',
#   'humidity': 71,
#   'id': 5278433229668352,
#   'max_temp': 18.66,
#   'min_temp': 14.004999999999999,
#   'predictability': 73,
#   'the_temp': 25.51,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 245.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 4.039641692515708},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T15:21:22.790570Z',
#   'humidity': 70,
#   'id': 5899704040685568,
#   'max_temp': 18.855,
#   'min_temp': 13.775,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 244.5,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.325064821442774},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T12:19:23.865262Z',
#   'humidity': 69,
#   'id': 5510983294386176,
#   'max_temp': 19.46,
#   'min_temp': 13.5,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 234.0,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.175064821442774},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T09:17:22.682611Z',
#   'humidity': 69,
#   'id': 4543732399472640,
#   'max_temp': 19.46,
#   'min_temp': 13.5,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 234.0,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.175064821442774},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T06:15:22.776793Z',
#   'humidity': 69,
#   'id': 5586886909231104,
#   'max_temp': 19.46,
#   'min_temp': 13.5,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 234.0,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.175064821442774},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T03:13:23.755341Z',
#   'humidity': 69,
#   'id': 6288794791706624,
#   'max_temp': 19.46,
#   'min_temp': 13.5,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 234.0,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.175064821442774},
#  {'air_pressure': 1018.84,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-03T00:11:21.961643Z',
#   'humidity': 69,
#   'id': 4936464779444224,
#   'max_temp': 19.46,
#   'min_temp': 13.5,
#   'predictability': 70,
#   'the_temp': 25.9,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 234.0,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.175064821442774},
#  {'air_pressure': 1021.56,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T21:09:26.364056Z',
#   'humidity': 66,
#   'id': 5278542617116672,
#   'max_temp': 20.085,
#   'min_temp': 12.83,
#   'predictability': 70,
#   'the_temp': 25.36,
#   'visibility': 9.997862483098704,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 169.5,
#   'wind_direction_compass': 'S',
#   'wind_speed': 1.7307844189930806},
#  {'air_pressure': 1020.72,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T18:07:26.273566Z',
#   'humidity': 72,
#   'id': 5178999502274560,
#   'max_temp': 18.490000000000002,
#   'min_temp': 13.715,
#   'predictability': 71,
#   'the_temp': 25.25,
#   'visibility': 8.419579654815875,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 181.99999999999997,
#   'wind_direction_compass': 'S',
#   'wind_speed': 3.7765101805456136},
#  {'air_pressure': 1020.72,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T15:05:25.768959Z',
#   'humidity': 72,
#   'id': 5199973773737984,
#   'max_temp': 18.490000000000002,
#   'min_temp': 13.715,
#   'predictability': 71,
#   'the_temp': 25.25,
#   'visibility': 8.419579654815875,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 181.99999999999997,
#   'wind_direction_compass': 'S',
#   'wind_speed': 3.7765101805456136},
#  {'air_pressure': 1020.72,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T12:03:25.561593Z',
#   'humidity': 72,
#   'id': 5370735868510208,
#   'max_temp': 18.490000000000002,
#   'min_temp': 13.715,
#   'predictability': 71,
#   'the_temp': 25.25,
#   'visibility': 8.419579654815875,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 181.99999999999997,
#   'wind_direction_compass': 'S',
#   'wind_speed': 3.7765101805456136},
#  {'air_pressure': 1018.36,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T09:01:25.660999Z',
#   'humidity': 71,
#   'id': 6619163374125056,
#   'max_temp': 19.115000000000002,
#   'min_temp': 14.08,
#   'predictability': 73,
#   'the_temp': 26.36,
#   'visibility': 8.419579654815875,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 193.49999999999997,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 4.09651634454784},
#  {'air_pressure': 1018.36,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T05:59:25.568660Z',
#   'humidity': 71,
#   'id': 4678753252802560,
#   'max_temp': 19.115000000000002,
#   'min_temp': 14.08,
#   'predictability': 73,
#   'the_temp': 26.36,
#   'visibility': 8.419579654815875,
#   'weather_state_abbr': 's',
#   'weather_state_name': 'Showers',
#   'wind_direction': 193.49999999999997,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 4.09651634454784},
#  {'air_pressure': 1018.5,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-02T02:57:25.587296Z',
#   'humidity': 70,
#   'id': 5317272115609600,
#   'max_temp': 19.125,
#   'min_temp': 13.39,
#   'predictability': 70,
#   'the_temp': 25.73,
#   'visibility': 9.99164877117633,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 199.0,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 4.21613338105464},
#  {'air_pressure': 1018.5,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T23:55:26.666770Z',
#   'humidity': 70,
#   'id': 5264367245328384,
#   'max_temp': 19.125,
#   'min_temp': 13.39,
#   'predictability': 70,
#   'the_temp': 25.73,
#   'visibility': 9.99164877117633,
#   'weather_state_abbr': 'lc',
#   'weather_state_name': 'Light Cloud',
#   'wind_direction': 199.0,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 4.21613338105464},
#  {'air_pressure': 1017.42,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T20:53:30.073794Z',
#   'humidity': 67,
#   'id': 4521096076328960,
#   'max_temp': 19.145,
#   'min_temp': 13.545,
#   'predictability': 71,
#   'the_temp': 26.21,
#   'visibility': 9.19007993319017,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 240.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.9172421061003737},
#  {'air_pressure': 1017.42,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T17:51:28.397523Z',
#   'humidity': 67,
#   'id': 4631805233725440,
#   'max_temp': 19.145,
#   'min_temp': 13.545,
#   'predictability': 71,
#   'the_temp': 26.21,
#   'visibility': 9.19007993319017,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 240.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.9172421061003737},
#  {'air_pressure': 1017.42,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T14:49:28.568953Z',
#   'humidity': 67,
#   'id': 6157064285978624,
#   'max_temp': 19.145,
#   'min_temp': 13.545,
#   'predictability': 71,
#   'the_temp': 26.21,
#   'visibility': 9.19007993319017,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 240.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 3.9172421061003737},
#  {'air_pressure': 1017.42,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T11:47:27.873492Z',
#   'humidity': 71,
#   'id': 6131539094011904,
#   'max_temp': 26.61,
#   'min_temp': 23.99,
#   'predictability': 71,
#   'the_temp': 26.21,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 241.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 0.9444842122007476},
#  {'air_pressure': 1018.66,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T08:45:29.823411Z',
#   'humidity': 78,
#   'id': 6004022387408896,
#   'max_temp': 27.12,
#   'min_temp': 24.25,
#   'predictability': 71,
#   'the_temp': 26.06,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 171.0,
#   'wind_direction_compass': 'S',
#   'wind_speed': 0.2982581722739203},
#  {'air_pressure': 1016.2,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T05:43:29.269729Z',
#   'humidity': 80,
#   'id': 6249503357140992,
#   'max_temp': 25.56,
#   'min_temp': 24.13,
#   'predictability': 77,
#   'the_temp': 25.36,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 215.99999999999997,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.268004851666269},
#  {'air_pressure': 1016.2,
#   'applicable_date': '2019-05-08',
#   'created': '2019-05-01T02:41:27.963240Z',
#   'humidity': 80,
#   'id': 4893215331188736,
#   'max_temp': 25.56,
#   'min_temp': 24.13,
#   'predictability': 77,
#   'the_temp': 25.36,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 215.99999999999997,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.268004851666269},
#  {'air_pressure': 1016.2,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T23:39:30.463665Z',
#   'humidity': 80,
#   'id': 4686815174852608,
#   'max_temp': 25.56,
#   'min_temp': 24.13,
#   'predictability': 77,
#   'the_temp': 25.36,
#   'visibility': None,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 215.99999999999997,
#   'wind_direction_compass': 'SW',
#   'wind_speed': 2.268004851666269},
#  {'air_pressure': 1018.16,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T20:37:32.076583Z',
#   'humidity': 75,
#   'id': 5289707015503872,
#   'max_temp': 26.13,
#   'min_temp': 24.59,
#   'predictability': 68,
#   'the_temp': 26.13,
#   'visibility': None,
#   'weather_state_abbr': 'c',
#   'weather_state_name': 'Clear',
#   'wind_direction': 199.0,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 2.0008152390042153},
#  {'air_pressure': 1016.54,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T17:35:31.483944Z',
#   'humidity': 70,
#   'id': 4624467584090112,
#   'max_temp': 25.57,
#   'min_temp': 23.65,
#   'predictability': 71,
#   'the_temp': 25.57,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 245.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 2.1996540205201622},
#  {'air_pressure': 1016.54,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T14:33:32.067021Z',
#   'humidity': 70,
#   'id': 4999162040942592,
#   'max_temp': 25.57,
#   'min_temp': 23.65,
#   'predictability': 71,
#   'the_temp': 25.57,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 245.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 2.1996540205201622},
#  {'air_pressure': 1017.67,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T11:31:31.856573Z',
#   'humidity': 64,
#   'id': 5296791396286464,
#   'max_temp': 25.56,
#   'min_temp': 23.4,
#   'predictability': 71,
#   'the_temp': 25.56,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 263.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 1.9697466793923486},
#  {'air_pressure': 1017.67,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T08:29:32.088350Z',
#   'humidity': 64,
#   'id': 5500976423239680,
#   'max_temp': 25.56,
#   'min_temp': 23.4,
#   'predictability': 71,
#   'the_temp': 25.56,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 263.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 1.9697466793923486},
#  {'air_pressure': 1017.67,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T05:27:31.584773Z',
#   'humidity': 64,
#   'id': 6462985948102656,
#   'max_temp': 25.56,
#   'min_temp': 23.4,
#   'predictability': 71,
#   'the_temp': 25.56,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 263.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 1.9697466793923486},
#  {'air_pressure': 1017.67,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-30T02:25:31.652969Z',
#   'humidity': 64,
#   'id': 6696128953188352,
#   'max_temp': 25.56,
#   'min_temp': 23.4,
#   'predictability': 71,
#   'the_temp': 25.56,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 263.0,
#   'wind_direction_compass': 'W',
#   'wind_speed': 1.9697466793923486},
#  {'air_pressure': 1016.54,
#   'applicable_date': '2019-05-08',
#   'created': '2019-04-29T23:23:32.476118Z',
#   'humidity': 70,
#   'id': 6611512493867008,
#   'max_temp': 25.57,
#   'min_temp': 23.65,
#   'predictability': 71,
#   'the_temp': 25.57,
#   'visibility': None,
#   'weather_state_abbr': 'hc',
#   'weather_state_name': 'Heavy Cloud',
#   'wind_direction': 245.0,
#   'wind_direction_compass': 'WSW',
#   'wind_speed': 2.1996540205201622}]

# %% [markdown]
# Данные на сайте собираются из разных источников. Можно посмотреть такие параметры, как атмосферное давление, максимальная и минимальная температура, скорость ветра, влажность, видимость и вероятность(предсказуемость) данного прогнозам.

# %%
pd.DataFrame(requests.get("https://www.metaweather.com/api/location/"+ str(ident)+"/2019/5/8/").json()).head()
# Out:
#    air_pressure applicable_date                      created  humidity  \
# 0       1016.52      2019-05-08  2019-05-07T13:23:10.693470Z        57
# 1       1016.52      2019-05-08  2019-05-07T10:21:11.596971Z        57
# 2       1016.52      2019-05-08  2019-05-07T07:19:11.369930Z        58
# 3       1015.95      2019-05-08  2019-05-07T04:17:10.663412Z        63
# 4       1010.95      2019-05-08  2019-05-07T01:15:11.856425Z        79
#
#                  id  max_temp  min_temp  predictability  the_temp  visibility  \
# 0  4629226038755328    19.145    12.435              70    19.525   16.460744
# 1  5305197318373376    19.145    12.435              70    19.525   16.460744
# 2  5199902705451008    19.145    12.435              70    19.445   17.488803
# 3  5651761383604224    19.840    12.940              70    19.505   17.488803
# 4  5401657854656512    19.840    12.940              73    17.140    6.955629
#
#   weather_state_abbr weather_state_name  wind_direction  \
# 0                 lc        Light Cloud      251.238434
# 1                 lc        Light Cloud      251.238434
# 2                 lc        Light Cloud      251.238434
# 3                 lc        Light Cloud      267.741467
# 4                  s            Showers      303.500000
#
#   wind_direction_compass  wind_speed
# 0                    WSW    3.944210
# 1                    WSW    3.944210
# 2                    WSW    3.824907
# 3                      W    3.360950
# 4                    WNW    3.502622
